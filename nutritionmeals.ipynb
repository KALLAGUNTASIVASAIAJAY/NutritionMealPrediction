# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\kalla\Downloads\archive (7).zip")

# %%
df
# Out:
#       Ages  Gender  Height  Weight     Activity Level Dietary Preference  \
# 0       25    Male     180      80  Moderately Active           Omnivore
# 1       32  Female     165      65     Lightly Active         Vegetarian
# 2       48    Male     175      95          Sedentary              Vegan
# 3       55  Female     160      70        Very Active           Omnivore
# 4       62    Male     170      85          Sedentary         Vegetarian
# ...    ...     ...     ...     ...                ...                ...
# 1693    53  Female     182      76          Sedentary              Vegan
# 1694    38    Male     150      76        Very Active              Vegan
# 1695    57    Male     165      73        Very Active              Vegan
# 1696    40    Male     166      91   Extremely Active              Vegan
# 1697    54  Female     198      75          Sedentary         Vegetarian
#
#       Daily Calorie Target  Protein  Sugar  Sodium  Calories  Carbohydrates  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df["Gender"]=lb.fit_transform(df["Gender"])

# %%
df["Breakfast Suggestion"]=lb.fit_transform(df["Breakfast Suggestion"])

# %%
df["Dinner Suggestion"]=lb.fit_transform(df["Dinner Suggestion"])
df["Activity Level"]=lb.fit_transform(df["Activity Level"])
df["Lunch Suggestion"]=lb.fit_transform(df["Lunch Suggestion"])
df["Dietary Preference"]=lb.fit_transform(df["Dietary Preference"])
df["Disease"]=lb.fit_transform(df["Disease"])
df["Snack Suggestion"]=lb.fit_transform(df["Snack Suggestion"])

# %%
df
# Out:
#       Ages  Gender  Height  Weight  Activity Level  Dietary Preference  \
# 0       25       1     180      80               2                   0
# 1       32       0     165      65               1                   3
# 2       48       1     175      95               3                   2
# 3       55       0     160      70               4                   0
# 4       62       1     170      85               3                   3
# ...    ...     ...     ...     ...             ...                 ...
# 1693    53       0     182      76               3                   2
# 1694    38       1     150      76               4                   2
# 1695    57       1     165      73               4                   2
# 1696    40       1     166      91               0                   2
# 1697    54       0     198      75               3                   3
#
#       Daily Calorie Target  Protein  Sugar  Sodium  Calories  Carbohydrates  \
# ...

# %%
y = df['Disease']
X = df[['Weight','Activity Level','Dietary Preference','Daily Calorie Target','Protein','Sugar','Sodium','Calories','Carbohydrates','Fiber','Fat','Breakfast Suggestion','Lunch Suggestion','Dinner Suggestion','Snack Suggestion']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,y_test)
# Out:
# 0.12621425333995873

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rf.score(X_test,y_test)
# Out:
# 0.9921568627450981

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(rf,X,y,cv=5)
# Out:
# c:\Users\kalla\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\model_selection\_split.py:776: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# array([0.98823529, 0.98235294, 0.99117647, 0.98230088, 0.98525074])

# %%
import pickle
with open('model.pickle','wb') as model_file:
    pickle.dump(rf,model_file)
